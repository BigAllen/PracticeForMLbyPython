# %%
import requests
res= requests.get('https://www.coingecko.com/en/price_charts/bitcoin/usd')
print (res.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"035a448c8e","applicationID":"63019027","transactionName":"dg5XEUYNWVtdQRdDF1wCXDpXClRFTEAXQA1aFg==","queueTime":1,"applicationTime":707,"agent":""}</script>
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'html.parser')
price = soup.select('.coin_portfolio_price_chart')[0].prettify().split('=')[2].replace(' data-vs-currency', '')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8">
#    <meta content="IE=edge" http-equiv="X-UA-Compatible">
#     <script type="text/javascript">
#      window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"035a448c8e","applicationID":"63019027","transactionName":"dg5XEUYNWVtdQRdDF1wCXDpXClRFTEAXQA1aFg==","queueTime":1,"applicationTime":707,"agent":""}
#     </script>
#     <script type="text/javascript">
# ...

# %%
import pandas
df = pandas.DataFrame(eval(eval(price)))
df.columns = ['time', 'price']
df.index = df['time']
df.head()
# Out:
#                       time    price
# time
# 1.509260e+12  1.509260e+12  5759.30
# 1.509260e+12  1.509260e+12  5770.39
# 1.509261e+12  1.509261e+12  5818.75
# 1.509261e+12  1.509261e+12  5815.15
# 1.509262e+12  1.509262e+12  5810.42

# %%
# %pylab inline
df['mvg'] = df['price'].rolling(window = 7).mean()
df[['price', 'mvg']].plot(kind = 'line')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print ('a\tb\tc')
print ('100\t200\t300')
print ('50\t100\t150')
# Out:
# a	b	c
# 100	200	300
# 50	100	150

# %%
link = 'http://img.appledaily.com.tw/images/ReNews/20171028/640_57a2257002c5a7f9a1c6b4e481bd8af4.jpg'
print (link.split('/')[-1])
print (link.split('/')[-2])
print (link.split('/')[-3])
print (link.split('/')[0])
print (link.split('/')[1])
print (link.split('/')[2])
# Out:
# 640_57a2257002c5a7f9a1c6b4e481bd8af4.jpg
# 20171028
# ReNews
# http:
#
# img.appledaily.com.tw

# %%
dic = {'a':100, 'b':'yes', 'c':0.98}

# %%
dic['a']
# Out:
# 100

# %%
dic['d']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-dedc2af341b8> in <module>()
# ----> 1 dic['d']
#
# KeyError: 'd'

# %%
dic.get('a')
# Out:
# 100

# %%
dic.get('d', 'haha')
# Out:
# 'haha'

# %%
dic['d']='new'

# %%
dic.keys()
# Out:
# dict_keys(['b', 'd', 'a', 'c'])

# %%
dic.values()
# Out:
# dict_values(['yes', 'new', 100, 0.98])

# %%
dic
# Out:
# {'a': 100, 'b': 'yes', 'c': 0.98, 'd': 'new'}

# %%
dic2 = {'e':'yahoo','f':'google','g':'facebook'}

# %%
dic2
# Out:
# {'e': 'yahoo', 'f': 'google', 'g': 'facebook'}

# %%
dic.update(dic2)

# %%
dic
# Out:
# {'a': 100,
#  'b': 'yes',
#  'c': 0.98,
#  'd': 'new',
#  'e': 'yahoo',
#  'f': 'google',
#  'g': 'facebook'}

# %%
x=set()
x.add(1)
x.add(2)
x.add(1)

# %%
x
# Out:
# {1, 2}

# %%
phones = ['0912345678','0912345679','0912345680','0913345678','0912344678']
sales = ['0912345678','0912345680','0913345678']
set(phones)-set(sales)
# Out:
# {'0912344678', '0912345679'}

# %%
set(phones)+set(sales)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-1aa8c5cddb44> in <module>()
# ----> 1 set(phones)+set(sales)
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
help(set)
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
# ...

# %%
news= ['民進黨台南市長初選\u30006選將電視辯論直播(0)', '?糖胖症死亡率增\u3000減重手術有助擺脫糖尿病...(0)', '【全紀錄】NBA今日7場戰績\u3000魔術毀馬刺...(0)', '同志遊行凱道出發\u3000北、南、西兵分3路線(0)', '【獨家活逮】郭書瑤掰了金陽5個月\u3000牽以綸...(58368)', '毛寶貝大玩萬聖變裝趴\u3000可愛萌樣迷倒大小朋...(76)', '造價上億釋迦山牟尼佛寺\u3000一夜燒光無人知(21519)', '基層警察的告白：男警女警 都需要從性別刻...(307)', '柬埔寨涉電信詐騙19台人遭強押到中國\u3000陸...(1)', '【不斷更新】萬人健行失序濺血\u3000北市僅出動...(177994)', '【天價片】秘書手抖錯訂經濟艙\u3000害老闆吃一...(179069)', '?強闖民宅砍傷屋主\u30004嫌到案辯稱砍錯人(308)', '「一例一休」修改\u3000工總商總表達肯定(542)', '高樓丟水袋砸車窗\u3000國中生說壓力大抒壓(652)', '萬人響應健行卻失序濺血\u3000官方還算不出有 ...(276)', '【同志遊行】林俊逸硬擠時間上街\u3000討婚姻平...(1483)', '走入移民世界感動觀眾\u3000華埠劇場贏國際大獎(853)', '【有片】新莊競技疊杯大賽\u3000參賽選手快手拚...(312)', '2018全球智慧城市\u3000台灣4城市入圍(711)', '【妳的美腿、她的青春】日坐12小時\u3000十年...(34404)', '不受重陽節登山活動影響\u3000柯Ｐ照常發萬聖節...(477)', 'LA 動漫展開鑼！全場都是神力女超人(3287)', '陳金德接宜蘭代理縣長？\u3000吳澤成：「不知道...(3220)', '挑戰蔣萬安？\u3000鄭麗文：不排除投入北市長選...(1137)', '日本18禁繪師畫台女\u3000「可愛、而且愛露腿...(1858)', '同志大遊行熱鬧展開\u3000彩虹旗現場飄揚(1185)', '【星機片】雙子座天下無敵\u3000金牛魔羯下周現...(1145)', '【不斷更新】同志凱道遊行開始\u3000萬人彩虹旗...(3175)', '【世界大賽片】太空人打爆達比修\u30005比3克...(56796)']

# %%
s=0
for rec in news:
    s += rec.count('同志')
s
# Out:
# 4

# %%
array=[]
for rec in news:
    if "同志" in rec:
        array.append('同志')
len(array)
# Out:
# 4

# %%
(rec.split('(')[1]).replace(')','')
# Out:
# '56796'

# %%
import math
s=[]
for rec in news:
    if '同志' in rec:
        a=rec.split('(')[1]
        b=a.replace(')','')
        s.append(int(b))
sum (s)
# Out:
# 5843

# %%
s=[1,2,3]
sum(s)
# Out:
# 6

# %%
heights = []
for i in [180,177,176,163,182]:
    if i >= 170:
        heights.append(i)
heights
# Out:
# [180, 177, 176, 182]

# %%
sum([int(rec.split('(')[1].replace(')','')) for rec in news if '同志' in rec])
# Out:
# 5843

# %%
sum([int(rec.split('(')[1].replace(')', '')) for rec in news if '同志' in rec])
# Out:
# 5843

# %%
import pandas
df = pandas.read_clipboard(sep=':',header=None)

# %%
print(df[0].tolist())
# Out:
# ['自從Alpha Go 擊敗全球頂尖棋士後，人工智慧（AI）開始取代大數據（Big Data）成為政府官員中最朗朗上口的科技詞彙。上從總統行政院長，下至部會首長都高調宣誓投資人工智慧。手筆最大的應屬科技部，宣布要用5 年投入新台幣 160 億元，發展AI的硬體設備、機器人、穿戴裝備，並建立AI的廠商聚落，一時全國上下可說沈浸在AI流行風中。', '其實不論是人工智慧或是大數據，一個關鍵都在數據的取得，並將數據整合和加值。每當這些質疑浮現時，政府總說臺灣具有許多完整的數據資料，諸如長達數十年的健保醫療數據、社會保險、交通、教育和稅務資料，以及更長的農業土壤和氣象水文數據，這些不同數據資料庫若串連後，能夠有效加值做為臺灣發展人工智慧（或大數據）的利基。這些論點乍聽來相當有說服力，善用既有資料的確能讓台灣在數據競爭上帶來優勢。', '空有資料寶藏，卻無法探勘', '但實情是即便至今，這些資料不但很少被政府或學界使用，不同資料庫間整合更是少見，遑論提供民間機構來利用這些數據。', '為什麼臺灣這些資料庫無法被整合和利用呢？這困境有外在的因素，也有內在的問題。', '內在問題在於許多政府官員，心態上不認為這些數據能對政策有助益，反倒認為這些資料在保存上造成困擾。也就是這種心態，使得各部會對外界申請的資料使用，常常以一句不符合資料蒐集目的為由拒絕；即便被上級單位要求開放資料，也認為開放資料就是增加業務。在這種「生雞蛋無，放雞屎有」心態下，各部會官員對資料開放持相當保守態度。', '更嚴重的問題來自於法律規範。', '台灣很多政府資料在早期蒐集時，並沒有取得民眾知情或許可，但數據要事後重新取得授權又困難重重。而個資法施行後，政府機關每每談資料色變，幾乎所有申請使用都以違反個資來拒絕。特別當串連各種不同數據資料庫時，更以數據整合後對個人隱私風險提高為由拒絕。這個法律困境，即使當初張善政貴為行政院副院長（後來當行政院長），力主推動開放政府和大數據，都在這些行政程序上吃盡苦頭，直到卸任仍然無法推動政府資料的整合和加值。', '個人今年剛好在史丹佛進修，發現美國開始仿照北歐國家建立資料中心，進行許多不同資料（稅務、戶口普查、醫療和教育等資料）串連。這些串連後資料，吸引不少年輕學者透過政府資料，評估政府政策的效果，並討論如何修正政策以提高效益。', '美國如何突破？', '當與這些學
# ...

# %%
! pip install pandas
# Out:
# ...
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
def test():
    print ('Hello world')

# %%
test()
# Out:
# Hello world

# %%
! pip install gTTS
# Out:
# ...
#   Running setup.py bdist_wheel for gTTS: started
#   Running setup.py bdist_wheel for gTTS: finished with status 'done'
#   Stored in directory: C:\Users\Allen\AppData\Local\pip\Cache\wheels\ef\e7\2e\066d7be1514f7c7fd6c942f4d09ae5460f9a3125829782d03d
#   Running setup.py bdist_wheel for gtts-token: started
#   Running setup.py bdist_wheel for gtts-token: finished with status 'done'
#   Stored in directory: C:\Users\Allen\AppData\Local\pip\Cache\wheels\a9\19\5d\2abe941153d0331bb7c2fbcd48ed8c36a67ca1d40bd572773e
# Successfully built gTTS gtts-token
# ...

# %%
from gtts import gTTS
tts = gTTS(text='各位大家晚安 晚安各位大家', lang='zh')
tts.save('testing.mp3')

# %%
a =[180,175,445,'aaaa',234]
new_high=[]
for high in a:
    try:
        new_high.append(round(high*0.39,2))
    except:
        new_high.append(None)
new_high
# Out:
# [70.2, 68.25, 173.55, None, 91.26]

# %%
f=open('test.txt','w')
f.write('This is a test~')
f.close()

# %%
with open('test.txt','w') as f:
    f.write('This is a test file again~\nAnd add a Text Line.')

# %%
with open('test.txt','r') as f:
    for line in f:
        print (line.strip())
# Out:
# This is a test file again~
# And add a Text Line.

# %%
with open('test.txt','r') as f:
    s=f.read()
s
# Out:
# 'This is a test file again~\nAnd add a Text Line.'

# %%
print(s)
# Out:
# This is a test file again~
# And add a Text Line.

# %%
s=0
with open('test.txt','r') as f:
    for line in f:
        s +=1
s
# Out:
# 2

# %%
text_ary=[]
with open('test.txt','r') as f:
    for line in f:
        text_ary.append(line)
print(text_ary)
# Out:
# ['This is a test file again~\n', 'And add a Text Line.']

# %%
len([line for line in open('test.txt','r')])
# Out:
# 2

# %%
# %pwd
# Out:
# 'C:\\Users\\Allen'

# %%
with open('c://Users//Allen/trump.txt','r') as f:
    trump = f.read()

# %%
dic ={}
for word in trump.lower().replace('.','').replace(',','').split():
    if not dic.get(word):
        dic[word]=1
    else:
        dic[word] += 1
#dic
#sorted(dic)
dic.items()
# Out:
# dict_items([('fallen', 1), ('we', 46), ('railways', 1), ('vision', 1), ('rebuild', 1), ('starting', 1), ('what', 1), ('follow', 2), ('off', 1), ('friday', 1), ('do', 3), ('dc', 2), ("we've", 1), ('large', 1), ('people', 9), ('power', 4), ('going', 1), ('america', 17), ('spent', 1), ('prospered', 1), ('defended', 1), ('look', 1), ('industries', 1), ('goodness', 1), ('leaves', 1), ('same', 6), ('today', 4), ('great', 6), ('is', 21), ('time', 2), ('across', 5), ('january', 2), ('flourished', 1), ('millions', 3), ('potential', 1), ('us', 2), ('earth', 2), ('robbed', 1), ('stolen', 1), ('enjoy', 1), ('belongs', 2), ('obama', 3), ('room', 1), ('pride', 1), ('here', 4), ('men', 2), ('jobs', 4), ('these', 3), ('ripped', 1), ('shine', 1), ('products', 1), ('my', 1), ('right', 5), ('roads', 1), ('nation’s', 3), ('thought', 1), ('another', 2), ('united', 3), ('a', 15), ('fight', 2), ('space', 1), ('remembered', 1), ('urban', 1), ('govern', 1), ('seen', 1), ('heart', 4), ('neighborhoods', 1), ('
# ...

# %%
import operator
swd=sorted(dic.items(), key=operator.itemgetter(1), reverse=True)

# %%
for word, cnt in swd:
    if cnt >= 10:
        print (word, cnt)
# Out:
# and 74
# the 71
# of 49
# our 48
# we 46
# will 40
# to 37
# is 21
# america 17
# for 17
# a 15
# in 14
# are 14
# – 13
# but 13
# american 12
# you 12
# be 12
# all 12
# their 11
# from 11
# your 11
# this 10
# not 10
# it 10

# %%
stopwords = ["a", "about", "above", "above", "across", "after", "afterwards", "again", "against", "all", "almost", "alone", "along", "already", "also","although","always","am","among", "amongst", "amoungst", "amount",  "an", "and", "another", "any","anyhow","anyone","anything","anyway", "anywhere", "are", "around", "as",  "at", "back","be","became", "because","become","becomes", "becoming", "been", "before", "beforehand", "behind", "being", "below", "beside", "besides", "between", "beyond", "bill", "both", "bottom","but", "by", "call", "can", "cannot", "cant", "co", "con", "could", "couldnt", "cry", "de", "describe", "detail", "do", "done", "down", "due", "during", "each", "eg", "eight", "either", "eleven","else", "elsewhere", "empty", "enough", "etc", "even", "ever", "every", "everyone", "everything", "everywhere", "except", "few", "fifteen", "fify", "fill", "find", "fire", "first", "five", "for", "former", "formerly", "forty", "found", "four", "from", "front", "full", "further", "get", "give", "go", "had", "has", "hasnt", "have", "he", "hence", "her", "here", "hereafter", "hereby", "herein", "hereupon", "hers", "herself", "him", "himself", "his", "how", "however", "hundred", "ie", "if", "in", "inc", "indeed", "interest", "into", "is", "it", "its", "itself", "keep", "last", "latter", "latterly", "least", "less", "ltd", "made", "many", "may", "me", "meanwhile", "might", "mill", "mine", "more", "moreover", "most", "mostly", "move", "much", "must", "my", "myself", "name", "namely", "neither", "never", "nevertheless", "next", "nine", "no", "nobody", "none", "noone", "nor", "not", "nothing", "now", "nowhere", "of", "off", "often", "on", "once", "one", "only", "onto", "or", "other", "others", "otherwise", "our", "ours", "ourselves", "out", "over", "own","part", "per", "perhaps", "please", "put", "rather", "re", "same", "see", "seem", "seemed", "seeming", "seems", "serious", "several", "she", "should", "show", "side", "since", "sincere", "six", "sixty", "so", "some", "somehow", "someone", "something", "sometime", "sometimes", "somewhere", "still", "such", "system", "take", "ten", "than", "that", "the", "their", "them", "themselves", "then", "thence", "there", "thereafter", "thereby", "therefore", "therein", "thereupon", "these", "they", "thickv", "thin", "third", "this", "those", "though", "three", "through", "throughout", "thru", "thus", "to", "together", "too", "top", "toward", "towards", "twelve", "twenty", "two", "un", "under", "until", "up", "upon", "us", "very", "via", "was", "we", "well", "were", "what", "whatever", "when", "whence", "whenever", "where", "whereafter", "whereas", "whereby", "wherein", "whereupon", "wherever", "whether", "which", "while", "whither", "who", "whoever", "whole", "whom", "whose", "why", "will", "with", "within", "without", "would", "yet", "you", "your", "yours", "yourself", "yourselves", "the"]
stopwords
# Out:
# ['a',
#  'about',
#  'above',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amoungst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'bill',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'call',
#  'can',
#  'cannot',
#  'cant',
#  'co',
#  'con',
#  'could',
#  'couldnt',
#  'cry',
#  'de',
#  'describe',
#  'detail',
#  'do',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eg',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
# ...

# %%
with open('c://Users//Allen/trump.txt','r') as f:
    trump=f.read()
    
words=trump.lower().replace('.','').replace(',','').split()
from collections import Counter
c=Counter(words)
for word, cnt in c.most_common(100):
    if word not in stopwords:
        print(word, cnt)
# Out:
# america 17
# – 13
# american 12
# people 9
# country 9
# great 6
# new 6
# president 6
# right 5
# make 5
# nation 5
# protected 5
# world 5
# power 4
# today 4
# jobs 4
# heart 4
# citizens 4
# bring 4
# americans 4
# dreams 4
# wealth 4
# millions 3
# obama 3
# nation’s 3
# united 3
# left 3
# borders 3
# washington 3
# countries 3
# government 3
# factories 3
# i 3
# capital 3
# let 3
# foreign 3
# day 3
# god 3
# families 3
# follow 2

# %%
! pip install jieba
# Out:
# ...
#   Running setup.py bdist_wheel for jieba: started
#   Running setup.py bdist_wheel for jieba: finished with status 'done'
#   Stored in directory: C:\Users\Allen\AppData\Local\pip\Cache\wheels\ce\32\de\c2be1db5f30804bc7f146ff698c52963f8aa11ba5049811b0d
# Successfully built jieba
# ...

# %%
with open ('C://Users//Allen/xi.txt','r', encoding='utf-8') as f:
    xi = f.read()

# %%
import jieba
words=[]
for word in jieba.cut(xi):
    words.append(word)

from collections import Counter
c=Counter(words)
for word, cnt in c.most_common(100):
    if len(word) >=2:
        print (word, cnt)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\Allen\AppData\Local\Temp\jieba.cache
# Loading model cost 3.617 seconds.
# Prefix dict has been built succesfully.
# 社會 238
# 發展 220
# 人民 183
# 中國 168
# 建設 147
# 堅持 127
# 全面 93
# 政治 88
# 制度 88
# 實現 85
# 主義 84
# 特色 79
# 民族 78
# 國家 77
# 推進 77
# 文化 75
# 加強 70
# 經濟 66
# 我們 64
# 體系 63
# 改革 62
# 必須 61
# 民主 57
# 中華 56
# 完善 55
# 領導 53
# 安全 51
# 時代 49
# 工作 44
# 我國 44
# 更加 44
# 治理 43
# 創新 41
# 基本 41
# 增強 41
# 不斷 41
# 生態 40
# 教育 40
# 偉大 39
# 推動 39
# 文明 38
# 思想 37
# 問題 37
# 歷史 36
# 體制 36
# 世界 36
# 加快 35
# 戰略 35
# 全黨 34
# 提高 34
# 深化 34
# 重大 34
# 組織 33
# 堅決 33
# 依法 32
# 能力 31
# 生活 30
# 法治 30
# 現代化 30
# 共同 29
# 軍隊 29
# 監督 28
# 保障 27
# 環境 27
